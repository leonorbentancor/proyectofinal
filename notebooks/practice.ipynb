# %% [markdown]
# ## Práctica
#
# Puedes utilizar este notebook para analisar el dataset propuesto

# %%
import streamlit as st
import pandas as pd
from sklearn import datasets
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing()
df_california = pd.DataFrame(housing.data, columns=housing.feature_names)
df_california["MedHouseVal"] = housing.target
df_california
df_california.dtypes
st.subheader  # Con esto se muestra còdigo en el streamlit
st.write
st.dataframe(df_california.head())
###Estilo de Vivienda
min_age = int(df_california[
                  "HouseAge"].min())  # Tengo los datos en float, y slider solo funciona con entero, entonces convierto a entero para utilizar la funcion.
max_age = int(df_california["HouseAge"].max())
house_age_range = st.sidebar.slider("Rango de Edad Mediana de la Casa", min_value=int(df_california['HouseAge'].min()), max_value=int(df_california['HouseAge'].max()), value=(min_age, max_age))
###Filtro de Vecindario
active_filtro = st.checkbox("Filtrar por Latitud Mínima")
lat_min = st.sidebar.number_input("Latitud mínima", min_value=float(df_california["Latitude"].min()),
                                  max_value=float(df_california["Latitude"].max()),
                                  value=float(df_california["Latitude"].min()))
df_filtered = df_filtered[df_filtered["Latitude"] >= lat_min]
import matplotlib.pyplot as plt

###Gráfico de Distribución del Target
st.subheader("Distribución del Valor Mediano de la Vivienda (MedHouseVal)")

fig, ax = plt.subplots()  # Crea el área donde dibujar
ax.hist(df_filtered["MedHouseVal"], bins=30)
ax.set_xlabel("MedHouseVal")
ax.set_ylabel("Frecuencia")
ax.set_title("Histograma del Valor Mediano de Vivienda")

st.pyplot(fig)  # Muestra la figura
###Gráfico de Dispersión (MedInc vs MedHouseVal)
st.subheader("Relación entre Ingresos y Valor de Vivienda")

fig2, ax2 = plt.subplots()
ax2.scatter(df_filtered["MedInc"], df_filtered["MedHouseVal"], alpha=0.5)  # Crea el gráfico de puntos
ax2.set_xlabel("Mediana de Ingresos (MedInc)")
ax2.set_ylabel("Valor Mediano de la Vivienda (MedHouseVal)")
ax2.set_title("Scatter Plot: MedInc vs MedHouseVal")

st.pyplot(fig2)
# Out:
# 2025-12-02 22:19:18.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.285
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\leono\PycharmProjects\proyectofinal\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-12-02 22:19:19.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.303 Session state does not function when running a script without `streamlit run`
# 2025-12-02 22:19:19.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 22:19:19.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 25
#      21 active_filtro = st.checkbox("Filtrar por Latitud Mínima")
#      22 lat_min = st.sidebar.number_input("Latitud mínima", min_value=float(df_california["Latitude"].min()),
#      23                                   max_value=float(df_california["Latitude"].max()),
#      24                                   value=float(df_california["Latitude"].min()))
# ---> 25 df_filtered = df_filtered[df_filtered["Latitude"] >= lat_min]
#      26 import matplotlib.pyplot as plt
#      28 ###Gráfico de Distribución del Target
#
# NameError: name 'df_filtered' is not defined
